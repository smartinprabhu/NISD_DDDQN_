# %%
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
import matplotlib.pyplot as plt

# Define your DQN class and functions
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Load and preprocess your video dataset
video_dataset = '/Users/martinprabhu/pythonObject1/output.mp4'
cap = cv2.VideoCapture(video_dataset)

def preprocess_frame(frame):
    # Resize the frame to a specific size
    new_width = 224
    new_height = 224
    resized_frame = cv2.resize(frame, (new_width, new_height))

    return resized_frame

# Initialize necessary variables and hyperparameters
state_size = 224 * 224 * 3  # Modify according to your input state dimensions
action_size = 2  # Modify according to your action space size

batch_size = 64
learning_rate = 0.001
num_episodes = 500
num_steps = 100
target_update_freq = 10
num_frames = 3  # Number of frames to stack for the state

epsilon = 1.0
epsilon_decay = 0.99
epsilon_min = 0.01
gamma = 0.99

# Create an instance of the DQN class
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dqn = DQN(state_size, action_size).to(device)
target_dqn = DQN(state_size, action_size).to(device)
target_dqn.load_state_dict(dqn.state_dict())
target_dqn.eval()

optimizer = optim.Adam(dqn.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

# Initialize replay memory
replay_memory = []

# Initialize variables for average episode length and average return
avg_episode_length = 0
avg_return = 0

# Initialize a list to store the episode lengths
episode_lengths = []

# Start training the DQN network
for episode in range(num_episodes):
    cap = cv2.VideoCapture(video_dataset)  # Assuming video_dataset is the path to your video file
    done = False
    total_reward = 0
    episode_length = 0

    for step in range(num_steps):
        ret, frame = cap.read()
        if not ret:
            break

        frame = preprocess_frame(frame)

        state = frame.flatten()  # Assuming the flattened frame is used as the state

        # Choose an action using epsilon-greedy policy
        if np.random.rand() < epsilon:
            action = np.random.randint(action_size)
        else:
            state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
            with torch.no_grad():
                q_values = target_dqn(state_tensor)
            action = torch.argmax(q_values).item()

        # Perform the action and get the next state, reward, and done signal
        # Perform your object tracking action here and update the state, reward, and done signal accordingly
        next_state = frame.flatten()  # Update the next state
        reward = 0  # Update the reward
        done = False  # Update the done signal

        # Store the transition in the replay memory
        replay_memory.append((state, action, reward, next_state, done))

        # Update the state
        state = next_state
        total_reward += reward
        episode_length += 1

        # Perform the DQN network update
        if len(replay_memory) >= batch_size:
            batch = random.sample(replay_memory, batch_size)
            state_batch, action_batch, reward_batch, next_state_batch, done_batch = zip(*batch)

            state_batch_array = np.array(state_batch)
            state_batch_tensor = torch.FloatTensor(state_batch_array).to(device)
            action_batch_tensor = torch.LongTensor(action_batch).unsqueeze(1).to(device)
            reward_batch_tensor = torch.FloatTensor(reward_batch).unsqueeze(1).to(device)
            next_state_batch_array = np.array(next_state_batch)
            next_state_batch_tensor = torch.FloatTensor(next_state_batch_array).to(device)
            done_batch_tensor = torch.FloatTensor(done_batch).unsqueeze(1).to(device)

            q_values = dqn(state_batch_tensor).gather(1, action_batch_tensor)
            target_q_values = target_dqn(next_state_batch_tensor).max(1)[0].unsqueeze(1).detach()
            target_q_values = reward_batch_tensor + gamma * target_q_values * (1 - done_batch_tensor)

            loss = criterion(q_values, target_q_values)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Update the target network
        if step % target_update_freq == 0:
            target_dqn.load_state_dict(dqn.state_dict())

        if done:
            break

    cap.release()  # Release the video capture

    # Decay epsilon
    epsilon = max(epsilon * epsilon_decay, epsilon_min)

    # Update average episode length and average return
    avg_episode_length += episode_length
    avg_return += total_reward

    # Append the episode length to the list
    episode_lengths.append(episode_length)

    # Print episode statistics
    print("Episode: {}, Total Reward: {}, Epsilon: {:.4f}".format(episode, total_reward, epsilon))

# Calculate the average episode length and average return
avg_episode_length /= num_episodes
avg_return /= num_episodes

# Print the average episode length and average return
print("Average Episode Length: {:.2f}".format(avg_episode_length))
print("Average Return: {:.2f}".format(avg_return))

# Plot the average episode length over epochs
plt.plot(range(1, num_episodes + 1), episode_lengths)
plt.xlabel("Epoch")
plt.ylabel("Average Episode Length")
plt.title("Average Episode Length per Epoch")
plt.show()
# Out:
# Episode: 0, Total Reward: 0, Epsilon: 0.9900
# Episode: 1, Total Reward: 0, Epsilon: 0.9801
# Episode: 2, Total Reward: 0, Epsilon: 0.9703
# Episode: 3, Total Reward: 0, Epsilon: 0.9606
# Episode: 4, Total Reward: 0, Epsilon: 0.9510
# Episode: 5, Total Reward: 0, Epsilon: 0.9415
# Episode: 6, Total Reward: 0, Epsilon: 0.9321
# Episode: 7, Total Reward: 0, Epsilon: 0.9227
# Episode: 8, Total Reward: 0, Epsilon: 0.9135
# Episode: 9, Total Reward: 0, Epsilon: 0.9044
# Episode: 10, Total Reward: 0, Epsilon: 0.8953
# Episode: 11, Total Reward: 0, Epsilon: 0.8864
# Episode: 12, Total Reward: 0, Epsilon: 0.8775
# Episode: 13, Total Reward: 0, Epsilon: 0.8687
# Episode: 14, Total Reward: 0, Epsilon: 0.8601
# Episode: 15, Total Reward: 0, Epsilon: 0.8515
# Episode: 16, Total Reward: 0, Epsilon: 0.8429
# Episode: 17, Total Reward: 0, Epsilon: 0.8345
# Episode: 18, Total Reward: 0, Epsilon: 0.8262
# Episode: 19, Total Reward: 0, Epsilon: 0.8179
# Episode: 20, Total Reward: 0, Epsilon: 0.8097
# Episode: 21, Total Reward: 0, Epsilon: 0.8016
# Episode: 22, Total Reward: 0, Epsilon: 0.7936
# Episode: 23, Total Reward: 0, Epsilon: 0.7857
# Episode: 24, Total Reward: 0, Epsilon: 0.7778
# Episode: 25, Total Reward: 0, Epsilon: 0.7700
# Episode: 26, Total Reward: 0, Epsilon: 0.7623
# Episode: 27, Total Reward: 0, Epsilon: 0.7547
# Episode: 28, Total Reward: 0, Epsilon: 0.7472
# Episode: 29, Total Reward: 0, Epsilon: 0.7397
# Episode: 30, Total Reward: 0, Epsilon: 0.7323
# Episode: 31, Total Reward: 0, Epsilon: 0.7250
# Episode: 32, Total Reward: 0, Epsilon: 0.7177
# Episode: 33, Total Reward: 0, Epsilon: 0.7106
# Episode: 34, Total Reward: 0, Epsilon: 0.7034
# Episode: 35, Total Reward: 0, Epsilon: 0.6964
# Episode: 36, Total Reward: 0, Epsilon: 0.6894
# Episode: 37, Total Reward: 0, Epsilon: 0.6826
# Episode: 38, Total Reward: 0, Epsilon: 0.6757
# Episode: 39, Total Reward: 0, Epsilon: 0.6690
# Episode: 40, Total Reward: 0, Epsilon: 0.6623
# Episode: 41, Total Reward: 0, Epsilon: 0.6557
# Episode: 42, Total Reward: 0, Epsilon: 0.6491
# Episode: 43, Total Reward: 0, Epsilon: 0.6426
# Episode: 44, Total Reward: 0, Epsilon: 0.6362
# Episode: 45, Total Reward: 0, Epsilon: 0.6298
# Episode: 46, Total Reward: 0, Epsilon: 0.6235
# Episode: 47, Total Reward: 0, Epsilon: 0.6173
# Episode: 48, Total Reward: 0, Epsilon: 0.6111
# Episode: 49, Total Reward: 0, Epsilon: 0.6050
# Episode: 50, Total Reward: 0, Epsilon: 0.5990
# Episode: 51, Total Reward: 0, Epsilon: 0.5930
# Episode: 52, Total Reward: 0, Epsilon: 0.5870
# Episode: 53, Total Reward: 0, Epsilon: 0.5812
# Episode: 54, Total Reward: 0, Epsilon: 0.5754
# Episode: 55, Total Reward: 0, Epsilon: 0.5696
# Episode: 56, Total Reward: 0, Epsilon: 0.5639
# Episode: 57, Total Reward: 0, Epsilon: 0.5583
# Episode: 58, Total Reward: 0, Epsilon: 0.5527
# Episode: 59, Total Reward: 0, Epsilon: 0.5472
# Episode: 60, Total Reward: 0, Epsilon: 0.5417
# Episode: 61, Total Reward: 0, Epsilon: 0.5363
# Episode: 62, Total Reward: 0, Epsilon: 0.5309
# Episode: 63, Total Reward: 0, Epsilon: 0.5256
# Episode: 64, Total Reward: 0, Epsilon: 0.5203
# Episode: 65, Total Reward: 0, Epsilon: 0.5151
# Episode: 66, Total Reward: 0, Epsilon: 0.5100
# Episode: 67, Total Reward: 0, Epsilon: 0.5049
# Episode: 68, Total Reward: 0, Epsilon: 0.4998
# Episode: 69, Total Reward: 0, Epsilon: 0.4948
# Episode: 70, Total Reward: 0, Epsilon: 0.4899
# Episode: 71, Total Reward: 0, Epsilon: 0.4850
# Episode: 72, Total Reward: 0, Epsilon: 0.4801
# Episode: 73, Total Reward: 0, Epsilon: 0.4753
# Episode: 74, Total Reward: 0, Epsilon: 0.4706
# Episode: 75, Total Reward: 0, Epsilon: 0.4659
# Episode: 76, Total Reward: 0, Epsilon: 0.4612
# Episode: 77, Total Reward: 0, Epsilon: 0.4566
# Episode: 78, Total Reward: 0, Epsilon: 0.4520
# Episode: 79, Total Reward: 0, Epsilon: 0.4475
# Episode: 80, Total Reward: 0, Epsilon: 0.4430
# Episode: 81, Total Reward: 0, Epsilon: 0.4386
# Episode: 82, Total Reward: 0, Epsilon: 0.4342
# Episode: 83, Total Reward: 0, Epsilon: 0.4299
# Episode: 84, Total Reward: 0, Epsilon: 0.4256
# Episode: 85, Total Reward: 0, Epsilon: 0.4213
# Episode: 86, Total Reward: 0, Epsilon: 0.4171
# Episode: 87, Total Reward: 0, Epsilon: 0.4129
# Episode: 88, Total Reward: 0, Epsilon: 0.4088
# Episode: 89, Total Reward: 0, Epsilon: 0.4047
# Episode: 90, Total Reward: 0, Epsilon: 0.4007
# Episode: 91, Total Reward: 0, Epsilon: 0.3967
# Episode: 92, Total Reward: 0, Epsilon: 0.3927
# Episode: 93, Total Reward: 0, Epsilon: 0.3888
# Episode: 94, Total Reward: 0, Epsilon: 0.3849
# Episode: 95, Total Reward: 0, Epsilon: 0.3810
# Episode: 96, Total Reward: 0, Epsilon: 0.3772
# Episode: 97, Total Reward: 0, Epsilon: 0.3735
# Episode: 98, Total Reward: 0, Epsilon: 0.3697
# Episode: 99, Total Reward: 0, Epsilon: 0.3660
# Episode: 100, Total Reward: 0, Epsilon: 0.3624
# Episode: 101, Total Reward: 0, Epsilon: 0.3587
# Episode: 102, Total Reward: 0, Epsilon: 0.3552
# Episode: 103, Total Reward: 0, Epsilon: 0.3516
# Episode: 104, Total Reward: 0, Epsilon: 0.3481
# Episode: 105, Total Reward: 0, Epsilon: 0.3446
# Episode: 106, Total Reward: 0, Epsilon: 0.3412
# Episode: 107, Total Reward: 0, Epsilon: 0.3378
# Episode: 108, Total Reward: 0, Epsilon: 0.3344
# Episode: 109, Total Reward: 0, Epsilon: 0.3310
# Episode: 110, Total Reward: 0, Epsilon: 0.3277
# Episode: 111, Total Reward: 0, Epsilon: 0.3244
# Episode: 112, Total Reward: 0, Epsilon: 0.3212
# Episode: 113, Total Reward: 0, Epsilon: 0.3180
# Episode: 114, Total Reward: 0, Epsilon: 0.3148
# Episode: 115, Total Reward: 0, Epsilon: 0.3117
# Episode: 116, Total Reward: 0, Epsilon: 0.3085
# Episode: 117, Total Reward: 0, Epsilon: 0.3055
# Episode: 118, Total Reward: 0, Epsilon: 0.3024
# Episode: 119, Total Reward: 0, Epsilon: 0.2994
# Episode: 120, Total Reward: 0, Epsilon: 0.2964
# Episode: 121, Total Reward: 0, Epsilon: 0.2934
# Episode: 122, Total Reward: 0, Epsilon: 0.2905
# Episode: 123, Total Reward: 0, Epsilon: 0.2876
# Episode: 124, Total Reward: 0, Epsilon: 0.2847
# Episode: 125, Total Reward: 0, Epsilon: 0.2819
# Episode: 126, Total Reward: 0, Epsilon: 0.2790
# Episode: 127, Total Reward: 0, Epsilon: 0.2763
# Episode: 128, Total Reward: 0, Epsilon: 0.2735
# Episode: 129, Total Reward: 0, Epsilon: 0.2708
# Episode: 130, Total Reward: 0, Epsilon: 0.2680
# Episode: 131, Total Reward: 0, Epsilon: 0.2654
# Episode: 132, Total Reward: 0, Epsilon: 0.2627
# Episode: 133, Total Reward: 0, Epsilon: 0.2601
# Episode: 134, Total Reward: 0, Epsilon: 0.2575
# Episode: 135, Total Reward: 0, Epsilon: 0.2549
# Episode: 136, Total Reward: 0, Epsilon: 0.2524
# Episode: 137, Total Reward: 0, Epsilon: 0.2498
# Episode: 138, Total Reward: 0, Epsilon: 0.2473
# Episode: 139, Total Reward: 0, Epsilon: 0.2449
# Episode: 140, Total Reward: 0, Epsilon: 0.2424
# Episode: 141, Total Reward: 0, Epsilon: 0.2400
# Episode: 142, Total Reward: 0, Epsilon: 0.2376
# Episode: 143, Total Reward: 0, Epsilon: 0.2352
# Episode: 144, Total Reward: 0, Epsilon: 0.2329
# Episode: 145, Total Reward: 0, Epsilon: 0.2305
# Episode: 146, Total Reward: 0, Epsilon: 0.2282
# Episode: 147, Total Reward: 0, Epsilon: 0.2259
# Episode: 148, Total Reward: 0, Epsilon: 0.2237
# Episode: 149, Total Reward: 0, Epsilon: 0.2215
# Episode: 150, Total Reward: 0, Epsilon: 0.2192
# Episode: 151, Total Reward: 0, Epsilon: 0.2170
# Episode: 152, Total Reward: 0, Epsilon: 0.2149
# Episode: 153, Total Reward: 0, Epsilon: 0.2127
# Episode: 154, Total Reward: 0, Epsilon: 0.2106
# Episode: 155, Total Reward: 0, Epsilon: 0.2085
# Episode: 156, Total Reward: 0, Epsilon: 0.2064
# Episode: 157, Total Reward: 0, Epsilon: 0.2043
# Episode: 158, Total Reward: 0, Epsilon: 0.2023
# Episode: 159, Total Reward: 0, Epsilon: 0.2003
# Episode: 160, Total Reward: 0, Epsilon: 0.1983
# Episode: 161, Total Reward: 0, Epsilon: 0.1963
# Episode: 162, Total Reward: 0, Epsilon: 0.1943
# Episode: 163, Total Reward: 0, Epsilon: 0.1924
# Episode: 164, Total Reward: 0, Epsilon: 0.1905
# Episode: 165, Total Reward: 0, Epsilon: 0.1886
# Episode: 166, Total Reward: 0, Epsilon: 0.1867
# Episode: 167, Total Reward: 0, Epsilon: 0.1848
# Episode: 168, Total Reward: 0, Epsilon: 0.1830
# Episode: 169, Total Reward: 0, Epsilon: 0.1811
# Episode: 170, Total Reward: 0, Epsilon: 0.1793
# Episode: 171, Total Reward: 0, Epsilon: 0.1775
# Episode: 172, Total Reward: 0, Epsilon: 0.1757
# Episode: 173, Total Reward: 0, Epsilon: 0.1740
# Episode: 174, Total Reward: 0, Epsilon: 0.1722
# Episode: 175, Total Reward: 0, Epsilon: 0.1705
# Episode: 176, Total Reward: 0, Epsilon: 0.1688
# Episode: 177, Total Reward: 0, Epsilon: 0.1671
# Episode: 178, Total Reward: 0, Epsilon: 0.1655
# Episode: 179, Total Reward: 0, Epsilon: 0.1638
# Episode: 180, Total Reward: 0, Epsilon: 0.1622
# Episode: 181, Total Reward: 0, Epsilon: 0.1605
# Episode: 182, Total Reward: 0, Epsilon: 0.1589
# Episode: 183, Total Reward: 0, Epsilon: 0.1574
# Episode: 184, Total Reward: 0, Epsilon: 0.1558
# Episode: 185, Total Reward: 0, Epsilon: 0.1542
# Episode: 186, Total Reward: 0, Epsilon: 0.1527
# Episode: 187, Total Reward: 0, Epsilon: 0.1512
# Episode: 188, Total Reward: 0, Epsilon: 0.1496
# Episode: 189, Total Reward: 0, Epsilon: 0.1481
# Episode: 190, Total Reward: 0, Epsilon: 0.1467
# Episode: 191, Total Reward: 0, Epsilon: 0.1452
# Episode: 192, Total Reward: 0, Epsilon: 0.1437
# Episode: 193, Total Reward: 0, Epsilon: 0.1423
# Episode: 194, Total Reward: 0, Epsilon: 0.1409
# Episode: 195, Total Reward: 0, Epsilon: 0.1395
# Episode: 196, Total Reward: 0, Epsilon: 0.1381
# Episode: 197, Total Reward: 0, Epsilon: 0.1367
# Episode: 198, Total Reward: 0, Epsilon: 0.1353
# Episode: 199, Total Reward: 0, Epsilon: 0.1340
# Episode: 200, Total Reward: 0, Epsilon: 0.1326
# Episode: 201, Total Reward: 0, Epsilon: 0.1313
# Episode: 202, Total Reward: 0, Epsilon: 0.1300
# Episode: 203, Total Reward: 0, Epsilon: 0.1287
# Episode: 204, Total Reward: 0, Epsilon: 0.1274
# Episode: 205, Total Reward: 0, Epsilon: 0.1261
# Episode: 206, Total Reward: 0, Epsilon: 0.1249
# Episode: 207, Total Reward: 0, Epsilon: 0.1236
# Episode: 208, Total Reward: 0, Epsilon: 0.1224
# Episode: 209, Total Reward: 0, Epsilon: 0.1212
# Episode: 210, Total Reward: 0, Epsilon: 0.1200
# Episode: 211, Total Reward: 0, Epsilon: 0.1188
# Episode: 212, Total Reward: 0, Epsilon: 0.1176
# Episode: 213, Total Reward: 0, Epsilon: 0.1164
# Episode: 214, Total Reward: 0, Epsilon: 0.1152
# Episode: 215, Total Reward: 0, Epsilon: 0.1141
# Episode: 216, Total Reward: 0, Epsilon: 0.1129
# Episode: 217, Total Reward: 0, Epsilon: 0.1118
# Episode: 218, Total Reward: 0, Epsilon: 0.1107
# Episode: 219, Total Reward: 0, Epsilon: 0.1096
# Episode: 220, Total Reward: 0, Epsilon: 0.1085
# Episode: 221, Total Reward: 0, Epsilon: 0.1074
# Episode: 222, Total Reward: 0, Epsilon: 0.1063
# Episode: 223, Total Reward: 0, Epsilon: 0.1053
# Episode: 224, Total Reward: 0, Epsilon: 0.1042
# Episode: 225, Total Reward: 0, Epsilon: 0.1032
# Episode: 226, Total Reward: 0, Epsilon: 0.1021
# Episode: 227, Total Reward: 0, Epsilon: 0.1011
# Episode: 228, Total Reward: 0, Epsilon: 0.1001
# Episode: 229, Total Reward: 0, Epsilon: 0.0991
# Episode: 230, Total Reward: 0, Epsilon: 0.0981
# Episode: 231, Total Reward: 0, Epsilon: 0.0971
# Episode: 232, Total Reward: 0, Epsilon: 0.0962
# Episode: 233, Total Reward: 0, Epsilon: 0.0952
# Episode: 234, Total Reward: 0, Epsilon: 0.0942
# Episode: 235, Total Reward: 0, Epsilon: 0.0933
# Episode: 236, Total Reward: 0, Epsilon: 0.0924
# Episode: 237, Total Reward: 0, Epsilon: 0.0914
# Episode: 238, Total Reward: 0, Epsilon: 0.0905
# Episode: 239, Total Reward: 0, Epsilon: 0.0896
# Episode: 240, Total Reward: 0, Epsilon: 0.0887
# Episode: 241, Total Reward: 0, Epsilon: 0.0878
# Episode: 242, Total Reward: 0, Epsilon: 0.0870
# Episode: 243, Total Reward: 0, Epsilon: 0.0861
# Episode: 244, Total Reward: 0, Epsilon: 0.0852
# Episode: 245, Total Reward: 0, Epsilon: 0.0844
# Episode: 246, Total Reward: 0, Epsilon: 0.0835
# Episode: 247, Total Reward: 0, Epsilon: 0.0827
# Episode: 248, Total Reward: 0, Epsilon: 0.0819
# Episode: 249, Total Reward: 0, Epsilon: 0.0811
# Episode: 250, Total Reward: 0, Epsilon: 0.0802
# Episode: 251, Total Reward: 0, Epsilon: 0.0794
# Episode: 252, Total Reward: 0, Epsilon: 0.0787
# Episode: 253, Total Reward: 0, Epsilon: 0.0779
# Episode: 254, Total Reward: 0, Epsilon: 0.0771
# Episode: 255, Total Reward: 0, Epsilon: 0.0763
# Episode: 256, Total Reward: 0, Epsilon: 0.0756
# Episode: 257, Total Reward: 0, Epsilon: 0.0748
# Episode: 258, Total Reward: 0, Epsilon: 0.0740
# Episode: 259, Total Reward: 0, Epsilon: 0.0733
# Episode: 260, Total Reward: 0, Epsilon: 0.0726
# Episode: 261, Total Reward: 0, Epsilon: 0.0718
# Episode: 262, Total Reward: 0, Epsilon: 0.0711
# Episode: 263, Total Reward: 0, Epsilon: 0.0704
# Episode: 264, Total Reward: 0, Epsilon: 0.0697
# Episode: 265, Total Reward: 0, Epsilon: 0.0690
# Episode: 266, Total Reward: 0, Epsilon: 0.0683
# Episode: 267, Total Reward: 0, Epsilon: 0.0676
# Episode: 268, Total Reward: 0, Epsilon: 0.0670
# Episode: 269, Total Reward: 0, Epsilon: 0.0663
# Episode: 270, Total Reward: 0, Epsilon: 0.0656
# Episode: 271, Total Reward: 0, Epsilon: 0.0650
# Episode: 272, Total Reward: 0, Epsilon: 0.0643
# Episode: 273, Total Reward: 0, Epsilon: 0.0637
# Episode: 274, Total Reward: 0, Epsilon: 0.0630
# Episode: 275, Total Reward: 0, Epsilon: 0.0624
# Episode: 276, Total Reward: 0, Epsilon: 0.0618
# Episode: 277, Total Reward: 0, Epsilon: 0.0612
# Episode: 278, Total Reward: 0, Epsilon: 0.0606
# Episode: 279, Total Reward: 0, Epsilon: 0.0600
# Episode: 280, Total Reward: 0, Epsilon: 0.0594
# Episode: 281, Total Reward: 0, Epsilon: 0.0588
# Episode: 282, Total Reward: 0, Epsilon: 0.0582
# Episode: 283, Total Reward: 0, Epsilon: 0.0576
# Episode: 284, Total Reward: 0, Epsilon: 0.0570
# Episode: 285, Total Reward: 0, Epsilon: 0.0565
# Episode: 286, Total Reward: 0, Epsilon: 0.0559
# Episode: 287, Total Reward: 0, Epsilon: 0.0553
# Episode: 288, Total Reward: 0, Epsilon: 0.0548
# Episode: 289, Total Reward: 0, Epsilon: 0.0542
# Episode: 290, Total Reward: 0, Epsilon: 0.0537
# Episode: 291, Total Reward: 0, Epsilon: 0.0531
# Episode: 292, Total Reward: 0, Epsilon: 0.0526
# Episode: 293, Total Reward: 0, Epsilon: 0.0521
# Episode: 294, Total Reward: 0, Epsilon: 0.0516
# Episode: 295, Total Reward: 0, Epsilon: 0.0511
# Episode: 296, Total Reward: 0, Epsilon: 0.0505
# Episode: 297, Total Reward: 0, Epsilon: 0.0500
# Episode: 298, Total Reward: 0, Epsilon: 0.0495
# Episode: 299, Total Reward: 0, Epsilon: 0.0490
# Episode: 300, Total Reward: 0, Epsilon: 0.0486
# Episode: 301, Total Reward: 0, Epsilon: 0.0481
# Episode: 302, Total Reward: 0, Epsilon: 0.0476
# Episode: 303, Total Reward: 0, Epsilon: 0.0471
# Episode: 304, Total Reward: 0, Epsilon: 0.0466
# Episode: 305, Total Reward: 0, Epsilon: 0.0462
# Episode: 306, Total Reward: 0, Epsilon: 0.0457
# Episode: 307, Total Reward: 0, Epsilon: 0.0453
# Episode: 308, Total Reward: 0, Epsilon: 0.0448
# Episode: 309, Total Reward: 0, Epsilon: 0.0444
# Episode: 310, Total Reward: 0, Epsilon: 0.0439
# Episode: 311, Total Reward: 0, Epsilon: 0.0435
# Episode: 312, Total Reward: 0, Epsilon: 0.0430
# Episode: 313, Total Reward: 0, Epsilon: 0.0426
# Episode: 314, Total Reward: 0, Epsilon: 0.0422
# Episode: 315, Total Reward: 0, Epsilon: 0.0418
# Episode: 316, Total Reward: 0, Epsilon: 0.0413
# Episode: 317, Total Reward: 0, Epsilon: 0.0409
# Episode: 318, Total Reward: 0, Epsilon: 0.0405
# Episode: 319, Total Reward: 0, Epsilon: 0.0401
# Episode: 320, Total Reward: 0, Epsilon: 0.0397
# Episode: 321, Total Reward: 0, Epsilon: 0.0393
# Episode: 322, Total Reward: 0, Epsilon: 0.0389
# Episode: 323, Total Reward: 0, Epsilon: 0.0385
# Episode: 324, Total Reward: 0, Epsilon: 0.0381
# Episode: 325, Total Reward: 0, Epsilon: 0.0378
# Episode: 326, Total Reward: 0, Epsilon: 0.0374
# Episode: 327, Total Reward: 0, Epsilon: 0.0370
# Episode: 328, Total Reward: 0, Epsilon: 0.0366
# Episode: 329, Total Reward: 0, Epsilon: 0.0363
# Episode: 330, Total Reward: 0, Epsilon: 0.0359
# Episode: 331, Total Reward: 0, Epsilon: 0.0356
# Episode: 332, Total Reward: 0, Epsilon: 0.0352
# Episode: 333, Total Reward: 0, Epsilon: 0.0348
# Episode: 334, Total Reward: 0, Epsilon: 0.0345
# Episode: 335, Total Reward: 0, Epsilon: 0.0342
# Episode: 336, Total Reward: 0, Epsilon: 0.0338
# Episode: 337, Total Reward: 0, Epsilon: 0.0335
# Episode: 338, Total Reward: 0, Epsilon: 0.0331
# Episode: 339, Total Reward: 0, Epsilon: 0.0328
# Episode: 340, Total Reward: 0, Epsilon: 0.0325
# Episode: 341, Total Reward: 0, Epsilon: 0.0322
# Episode: 342, Total Reward: 0, Epsilon: 0.0318
# Episode: 343, Total Reward: 0, Epsilon: 0.0315
# Episode: 344, Total Reward: 0, Epsilon: 0.0312
# Episode: 345, Total Reward: 0, Epsilon: 0.0309
# Episode: 346, Total Reward: 0, Epsilon: 0.0306
# Episode: 347, Total Reward: 0, Epsilon: 0.0303
# Episode: 348, Total Reward: 0, Epsilon: 0.0300
# Episode: 349, Total Reward: 0, Epsilon: 0.0297
# Episode: 350, Total Reward: 0, Epsilon: 0.0294
# Episode: 351, Total Reward: 0, Epsilon: 0.0291
# Episode: 352, Total Reward: 0, Epsilon: 0.0288
# Episode: 353, Total Reward: 0, Epsilon: 0.0285
# Episode: 354, Total Reward: 0, Epsilon: 0.0282
# Episode: 355, Total Reward: 0, Epsilon: 0.0279
# Episode: 356, Total Reward: 0, Epsilon: 0.0277
# Episode: 357, Total Reward: 0, Epsilon: 0.0274
# Episode: 358, Total Reward: 0, Epsilon: 0.0271
# Episode: 359, Total Reward: 0, Epsilon: 0.0268
# Episode: 360, Total Reward: 0, Epsilon: 0.0266
# Episode: 361, Total Reward: 0, Epsilon: 0.0263
# Episode: 362, Total Reward: 0, Epsilon: 0.0260
# Episode: 363, Total Reward: 0, Epsilon: 0.0258
# Episode: 364, Total Reward: 0, Epsilon: 0.0255
# Episode: 365, Total Reward: 0, Epsilon: 0.0253
# Episode: 366, Total Reward: 0, Epsilon: 0.0250
# Episode: 367, Total Reward: 0, Epsilon: 0.0248
# Episode: 368, Total Reward: 0, Epsilon: 0.0245
# Episode: 369, Total Reward: 0, Epsilon: 0.0243
# Episode: 370, Total Reward: 0, Epsilon: 0.0240
# Episode: 371, Total Reward: 0, Epsilon: 0.0238
# Episode: 372, Total Reward: 0, Epsilon: 0.0235
# Episode: 373, Total Reward: 0, Epsilon: 0.0233
# Episode: 374, Total Reward: 0, Epsilon: 0.0231
# Episode: 375, Total Reward: 0, Epsilon: 0.0228
# Episode: 376, Total Reward: 0, Epsilon: 0.0226
# Episode: 377, Total Reward: 0, Epsilon: 0.0224
# Episode: 378, Total Reward: 0, Epsilon: 0.0222
# Episode: 379, Total Reward: 0, Epsilon: 0.0219
# Episode: 380, Total Reward: 0, Epsilon: 0.0217
# Episode: 381, Total Reward: 0, Epsilon: 0.0215
# Episode: 382, Total Reward: 0, Epsilon: 0.0213
# Episode: 383, Total Reward: 0, Epsilon: 0.0211
# Episode: 384, Total Reward: 0, Epsilon: 0.0209
# Episode: 385, Total Reward: 0, Epsilon: 0.0207
# Episode: 386, Total Reward: 0, Epsilon: 0.0205
# Episode: 387, Total Reward: 0, Epsilon: 0.0203
# Episode: 388, Total Reward: 0, Epsilon: 0.0200
# Episode: 389, Total Reward: 0, Epsilon: 0.0198
# Episode: 390, Total Reward: 0, Epsilon: 0.0196
# Episode: 391, Total Reward: 0, Epsilon: 0.0195
# Episode: 392, Total Reward: 0, Epsilon: 0.0193
# Episode: 393, Total Reward: 0, Epsilon: 0.0191
# Episode: 394, Total Reward: 0, Epsilon: 0.0189
# Episode: 395, Total Reward: 0, Epsilon: 0.0187
# Episode: 396, Total Reward: 0, Epsilon: 0.0185
# Episode: 397, Total Reward: 0, Epsilon: 0.0183
# Episode: 398, Total Reward: 0, Epsilon: 0.0181
# Episode: 399, Total Reward: 0, Epsilon: 0.0180
# Episode: 400, Total Reward: 0, Epsilon: 0.0178
# Episode: 401, Total Reward: 0, Epsilon: 0.0176
# Episode: 402, Total Reward: 0, Epsilon: 0.0174
# Episode: 403, Total Reward: 0, Epsilon: 0.0172
# Episode: 404, Total Reward: 0, Epsilon: 0.0171
# Episode: 405, Total Reward: 0, Epsilon: 0.0169
# Episode: 406, Total Reward: 0, Epsilon: 0.0167
# Episode: 407, Total Reward: 0, Epsilon: 0.0166
# Episode: 408, Total Reward: 0, Epsilon: 0.0164
# Episode: 409, Total Reward: 0, Epsilon: 0.0162
# Episode: 410, Total Reward: 0, Epsilon: 0.0161
# Episode: 411, Total Reward: 0, Epsilon: 0.0159
# Episode: 412, Total Reward: 0, Epsilon: 0.0158
# Episode: 413, Total Reward: 0, Epsilon: 0.0156
# Episode: 414, Total Reward: 0, Epsilon: 0.0154
# Episode: 415, Total Reward: 0, Epsilon: 0.0153
# Episode: 416, Total Reward: 0, Epsilon: 0.0151
# Episode: 417, Total Reward: 0, Epsilon: 0.0150
# Episode: 418, Total Reward: 0, Epsilon: 0.0148
# Episode: 419, Total Reward: 0, Epsilon: 0.0147
# Episode: 420, Total Reward: 0, Epsilon: 0.0145
# Episode: 421, Total Reward: 0, Epsilon: 0.0144
# Episode: 422, Total Reward: 0, Epsilon: 0.0142
# Episode: 423, Total Reward: 0, Epsilon: 0.0141
# Episode: 424, Total Reward: 0, Epsilon: 0.0140
# Episode: 425, Total Reward: 0, Epsilon: 0.0138
# Episode: 426, Total Reward: 0, Epsilon: 0.0137
# Episode: 427, Total Reward: 0, Epsilon: 0.0135
# Episode: 428, Total Reward: 0, Epsilon: 0.0134
# Episode: 429, Total Reward: 0, Epsilon: 0.0133
# Episode: 430, Total Reward: 0, Epsilon: 0.0131
# Episode: 431, Total Reward: 0, Epsilon: 0.0130
# Episode: 432, Total Reward: 0, Epsilon: 0.0129
# Episode: 433, Total Reward: 0, Epsilon: 0.0128
# Episode: 434, Total Reward: 0, Epsilon: 0.0126
# Episode: 435, Total Reward: 0, Epsilon: 0.0125
# Episode: 436, Total Reward: 0, Epsilon: 0.0124
# Episode: 437, Total Reward: 0, Epsilon: 0.0123
# Episode: 438, Total Reward: 0, Epsilon: 0.0121
# Episode: 439, Total Reward: 0, Epsilon: 0.0120
# Episode: 440, Total Reward: 0, Epsilon: 0.0119
# Episode: 441, Total Reward: 0, Epsilon: 0.0118
# Episode: 442, Total Reward: 0, Epsilon: 0.0117
# Episode: 443, Total Reward: 0, Epsilon: 0.0115
# Episode: 444, Total Reward: 0, Epsilon: 0.0114
# Episode: 445, Total Reward: 0, Epsilon: 0.0113
# Episode: 446, Total Reward: 0, Epsilon: 0.0112
# Episode: 447, Total Reward: 0, Epsilon: 0.0111
# Episode: 448, Total Reward: 0, Epsilon: 0.0110
# Episode: 449, Total Reward: 0, Epsilon: 0.0109
# Episode: 450, Total Reward: 0, Epsilon: 0.0108
# Episode: 451, Total Reward: 0, Epsilon: 0.0106
# Episode: 452, Total Reward: 0, Epsilon: 0.0105
# Episode: 453, Total Reward: 0, Epsilon: 0.0104
# Episode: 454, Total Reward: 0, Epsilon: 0.0103
# Episode: 455, Total Reward: 0, Epsilon: 0.0102
# Episode: 456, Total Reward: 0, Epsilon: 0.0101
# Episode: 457, Total Reward: 0, Epsilon: 0.0100
# Episode: 458, Total Reward: 0, Epsilon: 0.0100
# Episode: 459, Total Reward: 0, Epsilon: 0.0100
# Episode: 460, Total Reward: 0, Epsilon: 0.0100
# Episode: 461, Total Reward: 0, Epsilon: 0.0100
